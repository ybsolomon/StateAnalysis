# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
map_df = gpd.read_file("NY-lab/NY.shp")
map_df.plot()
# Out:
# <Axes: >

# %%
map_df["Partisan Lean"] = map_df["G20PRER"]/(map_df["G20PRER"]+map_df["G20PRED"])
print(map_df["Partisan Lean"])
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 288814         NaN
# 288815    0.585903
# 288816    0.609455
# 288817         NaN
# 288818         NaN
# Name: Partisan Lean, Length: 288819, dtype: float64

# %%
fig, ax = plt.subplots(1, figsize=(10, 6))
ax.axis('off')
ax.set_title('Partisan lean', fontdict={'fontsize': '15', 'fontweight' : '3'})
colorscale = ["rgb(255, 51, 51)", "rgb(48, 48, 255)"]
map_df.plot(column='Partisan Lean',
            #cmap = "RdYlBu",
            cmap = 'coolwarm',
            #cmap='bwr',
            linewidth=0.05,
            ax=ax,
            edgecolor='0.4',
            vmin = 0,
            vmax = 1,
            legend=True, missing_kwds={
            "color": "lightgrey",
            "label": "Missing values",},)

plt.savefig('NY.png')
